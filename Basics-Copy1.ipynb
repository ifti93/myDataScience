# %% [markdown]
# ## In this guided project, I will work with a dataset of used cars from eBay Kleinanzeigen, a classifieds section of the German eBay website.
# ## Note
# ### Dataset is composed of 50,000 data points from the full dataset.
# ## Objective
# ### The aim of this project is to clean the data and analyze the included used car listings.

# %% [markdown]
# ### Step 1: Initial Exploration & Data Cleaning

# %%
import numpy as np
import pandas as pd
autos= pd.read_csv("autos.csv", encoding= "Windows-1252")
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
# Cleaning Column Names by modifying names from camelcase (eg, dateCrawled) to snakecase (eg, date_crawled)
autos.columns= ['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
       'vehicle_type', 'year_of_registration', 'gear_box', 'power_PS', 'model',
       'odometer', 'month_of_registration', 'fuel_type', 'brand',
       'not_repaired_damage', 'date_created', 'nr_of_pictures', 'postal_code',
       'last_seen']
#autos.columns autos= pd.read_csv("autos.csv", encoding= "Windows-1252")
autos.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'year_of_registration', 'gear_box', 'power_PS', 'model',
#        'odometer', 'month_of_registration', 'fuel_type', 'brand',
#        'not_repaired_damage', 'date_created', 'nr_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %%
autos.columns #display modified names of each column of dataframe
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'year_of_registration', 'gear_box', 'power_PS', 'model',
#        'odometer', 'month_of_registration', 'fuel_type', 'brand',
#        'not_repaired_damage', 'date_created', 'nr_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %%
import pandas as pd

# %%
autos
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
#display column names (it includes modified column names)
autos.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'year_of_registration', 'gear_box', 'power_PS', 'model',
#        'odometer', 'month_of_registration', 'fuel_type', 'brand',
#        'not_repaired_damage', 'date_created', 'nr_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %%
#autos.columns displays all existing column names, which are modified by a list of new names with snakecase convention (the ones with underscores _instead of camelcase postalCode would become postal_code)
autos.columns= ['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
       'vehicle_type', 'year_of_registration', 'gear_box', 'power_PS', 'model',
       'odometer', 'month_of_registration', 'fuel_type', 'brand',
       'not_repaired_damage', 'date_created', 'nr_of_pictures', 'postal_code',
       'last_seen']
 
autos.head() #displays first few rows including column labels & row labels. if you mention head(2) it will show only first two rows.
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  year_of_registration  \
# 0  privat    Angebot  $5,000  control          bus                  2004
# 1  privat    Angebot  $8,500  control    limousine                  1997
# 2  privat    Angebot  $8,990     test    limousine                  2009
# 3  privat    Angebot  $4,350  control   kleinwagen                  2007
# 4  privat    Angebot  $1,350     test        kombi                  2003
#
#     gear_box  power_PS   model   odometer  month_of_registration fuel_type  \
# ...

# %%
autos.describe()
# Out:
#        year_of_registration      power_PS  month_of_registration  \
# count          50000.000000  50000.000000           50000.000000
# mean            2005.073280    116.355920               5.723360
# std              105.712813    209.216627               3.711984
# min             1000.000000      0.000000               0.000000
# 25%             1999.000000     70.000000               3.000000
# 50%             2003.000000    105.000000               6.000000
# 75%             2008.000000    150.000000               9.000000
# max             9999.000000  17700.000000              12.000000
#
#        nr_of_pictures   postal_code
# count         50000.0  50000.000000
# mean              0.0  50813.627300
# std               0.0  25779.747957
# min               0.0   1067.000000
# 25%               0.0  30451.000000
# 50%               0.0  49577.000000
# 75%               0.0  71540.000000
# max               0.0  99998.000000

# %% [markdown]
# ### Instruction: Any examples of numeric data stored as text needs to be cleaned (it must be in numeric form)

# %%
#display pricing (defined as text/non-numeric initiated with "$"). 
#Our objective is to convert them to numeric form like int or float datatypes.
autos["price"]
# Out:
# 0         $5,000
# 1         $8,500
# 2         $8,990
# 3         $4,350
# 4         $1,350
# 5         $7,900
# 6           $300
# 7         $1,990
# 8           $250
# 9           $590
# 10          $999
# 11          $350
# 12        $5,299
# 13        $1,350
# 14        $3,999
# 15       $18,900
# 16          $350
# 17        $5,500
# 18          $300
# 19        $4,150
# 20        $3,500
# 21       $41,500
# 22       $25,450
# 23        $7,999
# 24       $48,500
# 25           $90
# 26          $777
# 27            $0
# 28        $5,250
# 29        $4,999
#           ...
# 49970    $15,800
# 49971       $950
# 49972     $3,300
# 49973     $6,000
# 49974         $0
# 49975     $9,700
# 49976     $5,900
# 49977     $5,500
# 49978       $900
# 49979    $11,000
# 49980       $400
# 49981     $2,000
# 49982     $1,950
# 49983       $600
# 49984         $0
# 49985     $1,000
# 49986    $15,900
# 49987    $21,990
# 49988     $9,550
# 49989       $150
# 49990    $17,500
# ...

# %%
autos["price"].values
# Out:
# array(['$5,000', '$8,500', '$8,990', ..., '$13,200', '$22,900', '$1,250'],
#       dtype=object)

# %%
autos["price"]= autos["price"].str.replace("$",'')

# %%
autos["price"].values
# Out:
# array(['5,000', '8,500', '8,990', ..., '13,200', '22,900', '1,250'],
#       dtype=object)

# %%
autos["price"]= autos["price"].astype(int)  
#Error: wrong way to convert price to int (numeric) from string/text (non numeric)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-38-9fa18aa01405> in <module>()
# ----> 1 autos["price"]= autos["price"].astype(int)
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# ...

# %%
# Correct way to do conversion/parsing datatype from text/string to int 
#replace([list of things to match],[if yes,do this],[enable "regex" by typing "True])
#modified price values by removing $ & , like $5,000 & then converting/parsing it to int or float (float is like int but with decimal support)
autos["price"]= autos["price"].replace('[$,]','',regex=True).astype(int)

# %%
# Display the prices in numeric form.
autos["price"]
# Out:
# 0         5000
# 1         8500
# 2         8990
# 3         4350
# 4         1350
# 5         7900
# 6          300
# 7         1990
# 8          250
# 9          590
# 10         999
# 11         350
# 12        5299
# 13        1350
# 14        3999
# 15       18900
# 16         350
# 17        5500
# 18         300
# 19        4150
# 20        3500
# 21       41500
# 22       25450
# 23        7999
# 24       48500
# 25          90
# 26         777
# 27           0
# 28        5250
# 29        4999
#          ...
# 49970    15800
# 49971      950
# 49972     3300
# 49973     6000
# 49974        0
# 49975     9700
# 49976     5900
# 49977     5500
# 49978      900
# 49979    11000
# 49980      400
# 49981     2000
# 49982     1950
# 49983      600
# 49984        0
# 49985     1000
# 49986    15900
# 49987    21990
# 49988     9550
# 49989      150
# 49990    17500
# 49991      500
# 49992     4800
# 49993     1650
# 49994     5000
# 49995    24900
# 49996     1980
# ...

# %%
autos["odometer"] 
#display values in one line you can also display dataframe "autos" like autos[column name].values
#As you see problem is data is not cleaned as it's showing km so its in string/text/non-numeric format, our goal is to convert
# it to numeric form , int would work so as float although if digits are not important, then better option is int due to 
# less memory/space allocation.
# Out:
# 0        150,000km
# 1        150,000km
# 2         70,000km
# 3         70,000km
# 4        150,000km
# 5        150,000km
# 6        150,000km
# 7        150,000km
# 8        150,000km
# 9        150,000km
# 10       150,000km
# 11       150,000km
# 12        50,000km
# 13       150,000km
# 14       150,000km
# 15        80,000km
# 16       150,000km
# 17       150,000km
# 18       150,000km
# 19       150,000km
# 20       150,000km
# 21       150,000km
# 22        10,000km
# 23       150,000km
# 24        30,000km
# 25       150,000km
# 26       125,000km
# 27       150,000km
# 28       150,000km
# 29       150,000km
#            ...
# 49970     60,000km
# 49971    150,000km
# 49972    150,000km
# 49973    150,000km
# 49974    150,000km
# 49975    100,000km
# 49976    150,000km
# 49977    150,000km
# 49978    150,000km
# 49979     70,000km
# 49980    125,000km
# 49981    150,000km
# 49982     90,000km
# 49983    150,000km
# 49984    150,000km
# 49985    150,000km
# ...

# %%
# Successful conversion/parsing from string to int
autos["odometer"]= autos["odometer"].replace("[,km]",'',regex=True) 
autos["odometer"]
# Out:
# 0        150000
# 1        150000
# 2         70000
# 3         70000
# 4        150000
# 5        150000
# 6        150000
# 7        150000
# 8        150000
# 9        150000
# 10       150000
# 11       150000
# 12        50000
# 13       150000
# 14       150000
# 15        80000
# 16       150000
# 17       150000
# 18       150000
# 19       150000
# 20       150000
# 21       150000
# 22        10000
# 23       150000
# 24        30000
# 25       150000
# 26       125000
# 27       150000
# 28       150000
# 29       150000
#           ...
# 49970     60000
# 49971    150000
# 49972    150000
# 49973    150000
# 49974    150000
# 49975    100000
# 49976    150000
# 49977    150000
# 49978    150000
# 49979     70000
# 49980    125000
# 49981    150000
# 49982     90000
# 49983    150000
# 49984    150000
# 49985    150000
# 49986    125000
# 49987     50000
# 49988    150000
# 49989    150000
# 49990     30000
# 49991    150000
# 49992    125000
# 49993    150000
# ...

# %%
autos["odometer"].astype(int)
# Out:
# 0        150000
# 1        150000
# 2         70000
# 3         70000
# 4        150000
# 5        150000
# 6        150000
# 7        150000
# 8        150000
# 9        150000
# 10       150000
# 11       150000
# 12        50000
# 13       150000
# 14       150000
# 15        80000
# 16       150000
# 17       150000
# 18       150000
# 19       150000
# 20       150000
# 21       150000
# 22        10000
# 23       150000
# 24        30000
# 25       150000
# 26       125000
# 27       150000
# 28       150000
# 29       150000
#           ...
# 49970     60000
# 49971    150000
# 49972    150000
# 49973    150000
# 49974    150000
# 49975    100000
# 49976    150000
# 49977    150000
# 49978    150000
# 49979     70000
# 49980    125000
# 49981    150000
# 49982     90000
# 49983    150000
# 49984    150000
# 49985    150000
# 49986    125000
# 49987     50000
# 49988    150000
# 49989    150000
# 49990     30000
# 49991    150000
# 49992    125000
# 49993    150000
# ...

# %% [markdown]
# ### Step 2: Exploring Odometer & Pricing Columns
# #### Objective: Analyze the columns using minimum and maximum values and look for any values that look unrealistically high or low (outliers) that we might want to remove.

# %%
autos.rename(index=str, columns={"odometer":"odometer_km"})

# %%
autos["odometer"].shape #autos[column name] will always give 1-d array which is a.k.a as Series in pandas, just like 1-d array in Numpy is known as vector
#Series is an object in Pandas library, its built-in, & has special functions just like Dataframe object has. 
#Simply whenever 1-d array is discussed in pandas, its known as Series.

# %%
autos["price"].head() #head() displays first few rows, probably first 5

# %%
autos["price"].value_counts()

# %%
autos["price"].sort_index(ascending=False) #sorts according to index aka row positioning, so if its descending it will show from bottom up. 
#default is ascending meaning if sort_index() is not provided any value as a parameter, it will default to ascending. So its not mandatory to provide argument/parameter to sort_index() of Series object.

# %%
autos["price"].sort_index().head() #having multiple functions on the same line is known as method chaining.

# %%
#removing outliers (the minimum & maximum value in an array)
#autos[(autos["price"]>5000) & (autos["price"]<500)] #1st way to filter outliers
sample_price_500_5000= autos[autos["price"].between(500,5000)]

sample_rows = sample_price_500_5000.shape[0]
total_rows = autos.shape[0]

print("Number of Sample rows",":",sample_rows)
print("Number of Total rows", ":",total_rows)
print("Percentage of Sample rows",":",(sample_rows/total_rows)*100,"%")
# Out:
# Number of Sample rows : 28103
# Number of Total rows : 50000
# Percentage of Sample rows : 56.206 %

# %% [markdown]
# # FACT FINDING
# # 56% OF CARS ON EBAY ARE PRICED BETWEEN 500 & 5000 US DOLLARS

# %% [markdown]
# ### Step 3: Exploring Date Columns

# %%
autos["date_crawled"].values
# Out:
# array(['2016-03-26 17:47:46', '2016-04-04 13:38:56',
#        '2016-03-26 18:57:24', ..., '2016-04-02 14:44:48',
#        '2016-03-08 19:25:42', '2016-03-14 00:42:12'], dtype=object)

# %%
#select the first 10 characters of a column
#.str is like a slicer/stripper that slices up to certain number of characters passed into as argument. 
my_date_only_rows= autos["date_crawled"].str[:10] #strip first 9 characters
my_date_only_rows
#don't consider the index shown in display, its not part of results, but its system made supplied by default to dataframe
# Out:
# 0        2016-03-26
# 1        2016-04-04
# 2        2016-03-26
# 3        2016-03-12
# 4        2016-04-01
# 5        2016-03-21
# 6        2016-03-20
# 7        2016-03-16
# 8        2016-03-22
# 9        2016-03-16
# 10       2016-03-15
# 11       2016-03-16
# 12       2016-03-31
# 13       2016-03-23
# 14       2016-03-23
# 15       2016-04-01
# 16       2016-03-16
# 17       2016-03-29
# 18       2016-03-26
# 19       2016-03-17
# 20       2016-03-05
# 21       2016-03-06
# 22       2016-03-28
# 23       2016-03-10
# 24       2016-04-03
# 25       2016-03-21
# 26       2016-04-03
# 27       2016-03-27
# 28       2016-03-19
# 29       2016-04-02
#             ...
# 49970    2016-03-21
# 49971    2016-03-29
# 49972    2016-03-26
# 49973    2016-03-27
# 49974    2016-03-20
# 49975    2016-03-27
# 49976    2016-03-19
# 49977    2016-03-31
# 49978    2016-04-04
# 49979    2016-03-20
# 49980    2016-03-12
# 49981    2016-03-15
# 49982    2016-03-29
# 49983    2016-03-06
# ...

# %% [markdown]
# # How to extract different combinations of date in PANDAS like by year only or in long formats like YYYY-MM or YYYY-MM-DD?
# Using .str attribute of Series object to trim/slim/slice the string according to size supplied in square brackets .str[n](remember a single row or column of dataframe is known as Series object else its a Dataframe object, & both objects have various unique functions & attributes & ".str" is one of them. So, if YYYY only then .str[:4] if YYYY-MM then .str[:7] or if YYYY-MM-DD then .str[:10]. **Remember number supplied after ":" in square brackets is excluded when slicing is done. So if 7 is mentioned then slicing will be done upto 6 characters only starting from 0 not 1.**

# %%
autos.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'year_of_registration', 'gear_box', 'power_PS', 'model',
#        'odometer', 'month_of_registration', 'fuel_type', 'brand',
#        'not_repaired_damage', 'date_created', 'nr_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %%
autos[["date_crawled","date_created","last_seen"]].describe()
# Out:
#                date_crawled         date_created            last_seen
# count                 50000                50000                50000
# unique                48213                   76                39481
# top     2016-03-21 20:37:19  2016-04-03 00:00:00  2016-04-07 06:17:27
# freq                      3                 1946                    8

# %%
#calculate the distribution of values in the date_crawled, ad_created, and last_seen
autos["date_crawled"].value_counts(normalize=True, dropna=False)
#normalization is a term used to make all values standardized. eg, student marks <=100 while subjects <=7 so to normalize either make all standard to percentage like 100% so 85/100 marks= 85% for 5 subjects= 5/7 = 71%, so both columns got % values out of 100%, this is normalization of columns.
# Out:
# 2016-03-21 20:37:19    0.00006
# 2016-03-14 20:50:02    0.00006
# 2016-03-25 19:57:10    0.00006
# 2016-03-23 19:38:20    0.00006
# 2016-03-23 18:39:34    0.00006
# 2016-03-30 19:48:02    0.00006
# 2016-04-02 11:37:04    0.00006
# 2016-03-30 17:37:35    0.00006
# 2016-04-04 16:40:33    0.00006
# 2016-04-02 15:49:30    0.00006
# 2016-03-10 15:36:24    0.00006
# 2016-03-21 16:37:21    0.00006
# 2016-03-08 10:40:35    0.00006
# 2016-03-09 11:54:38    0.00006
# 2016-03-11 22:38:16    0.00006
# 2016-03-22 09:51:06    0.00006
# 2016-03-05 16:57:05    0.00006
# 2016-03-27 22:55:05    0.00006
# 2016-03-12 16:06:22    0.00006
# 2016-03-16 21:50:53    0.00006
# 2016-03-29 23:42:13    0.00006
# 2016-03-19 17:36:18    0.00006
# 2016-03-21 21:52:22    0.00004
# 2016-03-14 20:46:50    0.00004
# 2016-03-19 16:56:32    0.00004
# 2016-04-05 10:50:06    0.00004
# 2016-03-21 15:39:22    0.00004
# 2016-04-03 15:54:52    0.00004
# 2016-03-29 19:37:22    0.00004
# 2016-03-08 16:53:24    0.00004
# ...

# %%
#sort by date in ascending order & also use method chaining
autos["date_crawled"].sort_index() #sort_index default is ascending, to do descending do this: sort_index(ascending=False)
# Out:
# 0        2016-03-26 17:47:46
# 1        2016-04-04 13:38:56
# 2        2016-03-26 18:57:24
# 3        2016-03-12 16:58:10
# 4        2016-04-01 14:38:50
# 5        2016-03-21 13:47:45
# 6        2016-03-20 17:55:21
# 7        2016-03-16 18:55:19
# 8        2016-03-22 16:51:34
# 9        2016-03-16 13:47:02
# 10       2016-03-15 01:41:36
# 11       2016-03-16 18:45:34
# 12       2016-03-31 19:48:22
# 13       2016-03-23 10:48:32
# 14       2016-03-23 11:50:46
# 15       2016-04-01 12:06:20
# 16       2016-03-16 14:59:02
# 17       2016-03-29 11:46:22
# 18       2016-03-26 19:57:44
# 19       2016-03-17 13:36:21
# 20       2016-03-05 19:57:31
# 21       2016-03-06 19:07:10
# 22       2016-03-28 20:50:54
# 23       2016-03-10 19:55:34
# 24       2016-04-03 11:57:02
# 25       2016-03-21 21:56:18
# 26       2016-04-03 22:46:28
# 27       2016-03-27 18:45:01
# 28       2016-03-19 21:56:19
# 29       2016-04-02 12:45:44
#                 ...
# 49970    2016-03-21 22:47:37
# ...
